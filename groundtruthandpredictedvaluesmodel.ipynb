# %%
y_true = [1, 1, 1, 0, 0, 1, 0, 1]

y_pred = [1, 1, 0, 0, 1, 0, 0, 1]

print("Actual values:", y_true)
print("Predicted values:", y_pred)
# Out:
# Actual values: [1, 1, 1, 0, 0, 1, 0, 1]
# Predicted values: [1, 1, 0, 0, 1, 0, 0, 1]
